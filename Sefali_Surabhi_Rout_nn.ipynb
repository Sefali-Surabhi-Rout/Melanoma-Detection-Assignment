# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout, BatchNormalization, Activation
from glob import glob

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds =tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='training',
            ) ##todo
# Out:
# Found 15739 files belonging to 9 classes.
# Using 12592 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
            data_dir_train,
            batch_size=batch_size,
            image_size=(img_height, img_width),
            seed=123,
            validation_split=0.2,
            subset='validation',
            )##todo
# Out:
# Found 15739 files belonging to 9 classes.
# Using 3147 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize

# creating arrays of labels and images

labels_np = np.empty(shape=(0,), dtype=np.int32)
images_np = np.empty(shape=(0, 180, 180, 3), dtype=np.float32)
for images, labels in train_ds.take(4):
    labels_np = np.hstack((labels_np, labels.numpy()))
    images_np = np.vstack((images_np, images.numpy()))

# show one random image for each class of the data

fig = plt.figure(figsize=(10, 10))
for i in range(len(class_names)):
    ax = plt.subplot(3, 3, i + 1)
    label_idx = np.where(labels_np[:]==i)[0]
    img_num = label_idx[np.random.randint(label_idx.shape[0])]
    plt.imshow(images_np[img_num].astype("uint8"))
    plt.title(class_names[i])
    plt.axis("off")
        
plt.show()

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
model = keras.Sequential()

# a normalisation layer to scale the RGB value to 0 and 1
model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))),


model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
          
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

# convert layer into 1-D
model.add(Flatten())

# fully connected layer
model.add(Dense(256, activation='relu'))

# the output layer
model.add(Dense(len(class_names)))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_24 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_18 (MaxPooli  (None, 90, 90, 16)        0
#  ng2D)
#
#  conv2d_25 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_19 (MaxPooli  (None, 45, 45, 32)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_20 (MaxPooli  (None, 22, 22, 64)        0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 22, 22, 128)       73856
#
#  max_pooling2d_21 (MaxPooli  (None, 11, 11, 128)       0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 11, 11, 128)       147584
#
#  conv2d_29 (Conv2D)          (None, 11, 11, 128)       147584
#
#  max_pooling2d_22 (MaxPooli  (None, 5, 5, 128)         0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 5, 5, 256)         295168
#
#  conv2d_31 (Conv2D)          (None, 5, 5, 256)         590080
#
#  max_pooling2d_23 (MaxPooli  (None, 2, 2, 256)         0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 1024)              0
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dense_7 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 1542569 (5.88 MB)
# Trainable params: 1542569 (5.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 394/394 [==============================] - 363s 842ms/step - loss: 2.1636 - accuracy: 0.1375 - val_loss: 2.0007 - val_accuracy: 0.1964
# Epoch 2/20
# 394/394 [==============================] - 302s 767ms/step - loss: 1.6538 - accuracy: 0.3352 - val_loss: 1.5441 - val_accuracy: 0.3813
# Epoch 3/20
# 394/394 [==============================] - 288s 730ms/step - loss: 1.4478 - accuracy: 0.4221 - val_loss: 1.3824 - val_accuracy: 0.4255
# Epoch 4/20
# 394/394 [==============================] - 276s 701ms/step - loss: 1.3108 - accuracy: 0.4879 - val_loss: 1.2429 - val_accuracy: 0.5014
# Epoch 5/20
# 394/394 [==============================] - 291s 738ms/step - loss: 1.1246 - accuracy: 0.5666 - val_loss: 1.0407 - val_accuracy: 0.6111
# Epoch 6/20
# 394/394 [==============================] - 280s 711ms/step - loss: 0.9473 - accuracy: 0.6434 - val_loss: 0.9064 - val_accuracy: 0.6530
# Epoch 7/20
# 394/394 [==============================] - 284s 721ms/step - loss: 0.7540 - accuracy: 0.7174 - val_loss: 0.6477 - val_accuracy: 0.7674
# Epoch 8/20
# 394/394 [==============================] - 277s 704ms/step - loss: 0.5850 - accuracy: 0.7880 - val_loss: 0.5632 - val_accuracy: 0.7928
# Epoch 9/20
# 394/394 [==============================] - 275s 698ms/step - loss: 0.4747 - accuracy: 0.8244 - val_loss: 0.4329 - val_accuracy: 0.8354
# Epoch 10/20
# 394/394 [==============================] - 285s 722ms/step - loss: 0.3644 - accuracy: 0.8661 - val_loss: 0.3926 - val_accuracy: 0.8665
# Epoch 11/20
# 394/394 [==============================] - 299s 758ms/step - loss: 0.3073 - accuracy: 0.8900 - val_loss: 0.3259 - val_accuracy: 0.8862
# Epoch 12/20
# 394/394 [==============================] - 277s 701ms/step - loss: 0.2350 - accuracy: 0.9120 - val_loss: 0.3695 - val_accuracy: 0.8723
# Epoch 13/20
# 394/394 [==============================] - 268s 680ms/step - loss: 0.2270 - accuracy: 0.9165 - val_loss: 0.4040 - val_accuracy: 0.8754
# Epoch 14/20
# 394/394 [==============================] - 272s 690ms/step - loss: 0.2117 - accuracy: 0.9199 - val_loss: 0.3182 - val_accuracy: 0.8955
# Epoch 15/20
# 394/394 [==============================] - 290s 736ms/step - loss: 0.2090 - accuracy: 0.9223 - val_loss: 0.3373 - val_accuracy: 0.8935
# Epoch 16/20
# 394/394 [==============================] - 1447s 4s/step - loss: 0.1917 - accuracy: 0.9290 - val_loss: 0.2733 - val_accuracy: 0.9142
# Epoch 17/20
# 394/394 [==============================] - 1966s 5s/step - loss: 0.1746 - accuracy: 0.9346 - val_loss: 0.2962 - val_accuracy: 0.9063
# Epoch 18/20
# 394/394 [==============================] - 425s 1s/step - loss: 0.1571 - accuracy: 0.9386 - val_loss: 0.2659 - val_accuracy: 0.9152
# Epoch 19/20
# 394/394 [==============================] - 418s 1s/step - loss: 0.1619 - accuracy: 0.9381 - val_loss: 0.2314 - val_accuracy: 0.9266
# Epoch 20/20
# 394/394 [==============================] - 599s 2s/step - loss: 0.1654 - accuracy: 0.9366 - val_loss: 0.2858 - val_accuracy: 0.9037

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# - Though there is not much significant difference between the Training accuracy and validation accurracy, the model seem to be a little overfitting.
# - There is consistent decrease in training and validation loss which suggest that the model is learning.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# Your code goes here
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
  layers.experimental.preprocessing.RandomZoom(height_factor=(0.2,0.3), width_factor=(0.2,0.3))  
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
### Your code goes here
model = keras.Sequential()

# a normalisation layer to scale the RGB value to 0 and 1
model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))),

model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
          
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

# trying to reduce overfitting by adding dropout
model.add(Dropout(0.3))

# convert layer into 1-D
model.add(Flatten())

# fully connected layer
model.add(Dense(256, activation='relu'))

# we will try to reduce overfitting by adding dropout
model.add(Dropout(0.25))

# the output layer
model.add(Dense(len(class_names)))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_32 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_24 (MaxPooli  (None, 90, 90, 16)        0
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_25 (MaxPooli  (None, 45, 45, 32)        0
#  ng2D)
#
#  conv2d_34 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_26 (MaxPooli  (None, 22, 22, 64)        0
#  ng2D)
#
#  conv2d_35 (Conv2D)          (None, 22, 22, 128)       73856
#
#  max_pooling2d_27 (MaxPooli  (None, 11, 11, 128)       0
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 11, 11, 128)       147584
#
#  conv2d_37 (Conv2D)          (None, 11, 11, 128)       147584
#
#  max_pooling2d_28 (MaxPooli  (None, 5, 5, 128)         0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 5, 5, 256)         295168
#
#  conv2d_39 (Conv2D)          (None, 5, 5, 256)         590080
#
#  max_pooling2d_29 (MaxPooli  (None, 2, 2, 256)         0
#  ng2D)
#
#  dropout_4 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten_4 (Flatten)         (None, 1024)              0
#
#  dense_8 (Dense)             (None, 256)               262400
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 1542569 (5.88 MB)
# Trainable params: 1542569 (5.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs)## your training code
# Out:
# Epoch 1/20
# 394/394 [==============================] - 402s 1s/step - loss: 2.1926 - accuracy: 0.1253 - val_loss: 2.1940 - val_accuracy: 0.1265
# Epoch 2/20
# 394/394 [==============================] - 399s 1s/step - loss: 2.1945 - accuracy: 0.1252 - val_loss: 2.1935 - val_accuracy: 0.1265
# Epoch 3/20
# 394/394 [==============================] - 394s 999ms/step - loss: 2.1940 - accuracy: 0.1246 - val_loss: 2.1936 - val_accuracy: 0.1265
# Epoch 4/20
# 394/394 [==============================] - 328s 832ms/step - loss: 2.1943 - accuracy: 0.1251 - val_loss: 2.1939 - val_accuracy: 0.1153
# Epoch 5/20
# 394/394 [==============================] - 270s 684ms/step - loss: 2.1942 - accuracy: 0.1259 - val_loss: 2.1938 - val_accuracy: 0.1265
# Epoch 6/20
# 394/394 [==============================] - 270s 683ms/step - loss: 2.1941 - accuracy: 0.1236 - val_loss: 2.1939 - val_accuracy: 0.1153
# Epoch 7/20
# 394/394 [==============================] - 271s 687ms/step - loss: 2.1940 - accuracy: 0.1234 - val_loss: 2.1938 - val_accuracy: 0.1153
# Epoch 8/20
# 394/394 [==============================] - 270s 684ms/step - loss: 2.1942 - accuracy: 0.1229 - val_loss: 2.1935 - val_accuracy: 0.1265
# Epoch 9/20
# 394/394 [==============================] - 270s 685ms/step - loss: 2.1941 - accuracy: 0.1219 - val_loss: 2.1937 - val_accuracy: 0.1153
# Epoch 10/20
# 394/394 [==============================] - 295s 748ms/step - loss: 2.1942 - accuracy: 0.1220 - val_loss: 2.1937 - val_accuracy: 0.1265
# Epoch 11/20
# 394/394 [==============================] - 293s 744ms/step - loss: 2.1941 - accuracy: 0.1220 - val_loss: 2.1937 - val_accuracy: 0.1153
# Epoch 12/20
# 394/394 [==============================] - 286s 725ms/step - loss: 2.1940 - accuracy: 0.1242 - val_loss: 2.1937 - val_accuracy: 0.1265
# Epoch 13/20
# 394/394 [==============================] - 279s 708ms/step - loss: 2.1942 - accuracy: 0.1214 - val_loss: 2.1938 - val_accuracy: 0.1153
# Epoch 14/20
# 394/394 [==============================] - 271s 687ms/step - loss: 2.1939 - accuracy: 0.1217 - val_loss: 2.1937 - val_accuracy: 0.1153
# Epoch 15/20
# 394/394 [==============================] - 272s 691ms/step - loss: 2.1941 - accuracy: 0.1221 - val_loss: 2.1937 - val_accuracy: 0.1153
# Epoch 16/20
# 394/394 [==============================] - 272s 691ms/step - loss: 2.1940 - accuracy: 0.1227 - val_loss: 2.1937 - val_accuracy: 0.1153
# Epoch 17/20
# 394/394 [==============================] - 273s 692ms/step - loss: 2.1940 - accuracy: 0.1243 - val_loss: 2.1937 - val_accuracy: 0.1153
# Epoch 18/20
# 394/394 [==============================] - 270s 685ms/step - loss: 2.1940 - accuracy: 0.1239 - val_loss: 2.1939 - val_accuracy: 0.1153
# Epoch 19/20
# 394/394 [==============================] - 268s 679ms/step - loss: 2.1939 - accuracy: 0.1251 - val_loss: 2.1939 - val_accuracy: 0.1153
# Epoch 20/20
# 394/394 [==============================] - 282s 714ms/step - loss: 2.1941 - accuracy: 0.1248 - val_loss: 2.1939 - val_accuracy: 0.1153

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# Performance of the model become worse after addition of dropout layer.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
path_list=[]
lesion_list=[]
for i in class_names:
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns=['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 1     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 2     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 3     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# 4     CNN_assignment\Skin cancer ISIC The Internatio...  actinic keratosis
# ...                                                 ...                ...
# 2234  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2235  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2236  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2237  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
# 2238  CNN_assignment\Skin cancer ISIC The Internatio...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
original_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %%
original_df['Label'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#
# Seborrheic keratosis has the least number of samples.
#
# #### - Which classes dominate the data in terms proportionate number of samples?
#
# pigmented benign keratosis has the highest number of samples followed by melanoma, basal cell carcinoma and nevus.
# pigmented benign keratosis    462 samples
# melanoma                      438 samples
# basal cell carcinoma          376 samples
# nevus                         357 samples
# These four classes constitutes approximately 73 percentile of the total samples confirming presence of class imbalance.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
#!pip install Augmentor

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1F38E8BC520>: 100%|██████████| 500/500 [00:05<00:00, 95.99 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1F38E822850>: 100%|██████████| 500/500 [00:05<00:00, 86.53 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1F38E7E2190>: 100%|██████████| 500/500 [00:05<00:00, 92.46 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x1F384683940>: 100%|██████████| 500/500 [00:26<00:00, 19.04 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1F38E888D30>: 100%|██████████| 500/500 [00:22<00:00, 22.34 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1F38E7F19A0>: 100%|██████████| 500/500 [00:05<00:00, 91.72 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x1F38E8A3E50>: 100%|██████████| 500/500 [00:11<00:00, 44.23 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x1F38E8BCE50>: 100%|██████████| 500/500 [00:05<00:00, 88.19 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x1F38E87FD90>: 100%|██████████| 500/500 [00:05<00:00, 96.28 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 18000

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0025780.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0025803.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0025825.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0025953.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0025957.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0025992.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026040.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026149.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026171.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026194.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026212.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026457.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026468.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026525.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026575.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026625.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026626.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026650.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026702.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026709.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026729.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026765.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026848.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026857.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026905.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0026984.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027172.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027254.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027334.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027447.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027452.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027536.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027562.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027580.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027615.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027650.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027668.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027802.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027829.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027884.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027896.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027950.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0027958.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028063.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028076.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028190.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028314.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028370.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028393.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028517.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028558.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028820.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028854.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028941.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0028990.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029025.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029041.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029133.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029141.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029210.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029309.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029460.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029500.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029659.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029713.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029781.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029827.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029830.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029840.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029900.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029915.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0029930.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030036.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030133.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030142.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030143.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030242.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030344.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030408.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030463.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030491.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030586.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030655.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030730.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030825.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030826.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0030877.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031040.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031108.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031228.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031292.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031335.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031381.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031430.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031506.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031609.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031823.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031922.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0031993.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0032135.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0032199.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0032206.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0032404.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0032422.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0032437.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0032854.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033151.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033358.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033413.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033456.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033494.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033705.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033811.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\ISIC_0033866.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024504.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024515.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024550.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024564.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024572.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024573.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024582.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024590.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024595.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024632.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024634.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024665.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024666.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024673.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024743.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024787.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024795.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024799.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024829.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024833.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024848.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024885.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024897.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024931.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024949.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0024984.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025019.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025031.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025046.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025102.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025144.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025260.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025266.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025285.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025299.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025301.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025322.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025362.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025383.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025417.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025433.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025467.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025509.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025513.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025530.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025557.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025576.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025601.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025617.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025630.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025644.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025650.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025691.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025700.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025711.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025718.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025731.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025752.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025793.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025818.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025824.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025826.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025932.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025940.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025971.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0025975.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026056.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026074.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026090.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026091.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026117.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026118.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026154.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026192.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026213.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026230.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026275.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026282.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026321.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026324.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026337.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026343.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026350.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026395.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026433.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026439.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026442.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026453.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026496.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026528.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026574.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026593.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026643.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026656.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026668.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026687.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026716.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026760.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026766.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026798.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026829.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026831.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026845.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026855.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026865.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026902.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026940.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026952.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026968.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026970.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026978.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026988.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0026995.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027004.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027038.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027046.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027057.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027058.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027090.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027093.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027117.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027120.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027135.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027146.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027175.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027189.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027229.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027281.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027291.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027297.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027337.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027371.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027425.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027433.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027473.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027478.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027525.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027526.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027531.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027544.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027545.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027546.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027595.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027601.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027609.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027629.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027631.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027675.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027677.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027704.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027722.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027744.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027759.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027774.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027786.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027788.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027814.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027819.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027825.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027846.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027851.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027858.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027865.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027915.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027920.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027966.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027976.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0027998.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028035.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028050.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028059.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028079.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028084.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028085.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028095.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028106.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028107.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028113.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028122.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028147.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028155.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028168.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028197.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028238.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028283.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028303.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028316.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028323.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028329.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028350.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028419.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028457.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028486.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028495.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028542.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028556.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028568.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028570.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028577.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028583.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028652.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028653.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028670.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028671.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028677.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028687.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028688.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028693.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028719.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028728.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028739.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028747.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028765.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028807.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028814.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028815.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028818.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028858.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028871.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028877.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028890.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028928.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028937.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028964.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028973.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028978.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028980.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028989.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0028994.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029020.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029034.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029035.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029053.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029082.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029083.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029123.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029129.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029192.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029193.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029201.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029220.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029230.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029263.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029278.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029323.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029331.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029337.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029341.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029342.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029352.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029372.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029391.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029392.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029412.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029466.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029489.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029501.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029515.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029524.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\basal cell carcinoma\\ISIC_0029539.jpg',
# ...
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010466.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010468.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010469.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010470.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010476.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010478.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010482.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010485.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010486.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010503.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010514.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010516.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010527.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010532.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010533.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010534.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010536.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010537.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010543.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010546.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010548.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010550.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010551.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010555.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010559.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010564.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010576.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010579.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010580.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010583.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010587.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010591.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010596.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010597.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010608.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010609.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010610.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010611.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010629.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010630.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010631.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010644.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010648.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010652.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010653.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010655.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010663.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010690.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010707.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010714.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010719.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010723.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010728.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010729.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010730.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010737.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010741.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010746.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010749.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010750.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010754.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010757.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010759.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010765.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010766.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010767.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010770.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010772.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010777.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010778.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010782.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010783.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010784.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010785.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010789.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010790.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010791.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010792.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010796.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010797.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010799.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010803.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010808.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010809.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010810.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010812.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010834.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010852.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010860.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010862.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010863.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010866.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010872.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010876.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010878.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010883.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010890.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010898.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010900.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010909.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010912.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010917.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010923.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010925.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010934.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010938.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010942.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010965.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010971.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010977.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010978.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010979.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010982.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010990.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010993.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0010995.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011007.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011012.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011013.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011030.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011031.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011032.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011039.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011040.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011042.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011043.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011045.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011052.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011056.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011057.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011077.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011094.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011095.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011099.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011112.jpg',
#  'CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\melanoma\\ISIC_0011121.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  'actinic keratosis',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# C:\Users\sefal\AppData\Local\Temp\ipykernel_17648\390629722.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    2462
# melanoma                      2438
# basal cell carcinoma          2376
# nevus                         2357
# squamous cell carcinoma       2181
# vascular lesion               2139
# actinic keratosis             2114
# dermatofibroma                2095
# seborrheic keratosis          2077
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
data_dir_train="CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',## Todo choose the correct parameter value, so that only training data is refered to,,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 20239 files belonging to 9 classes.
# Using 16192 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation', ## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 20239 files belonging to 9 classes.
# Using 4047 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here
model = keras.Sequential()

# a normalisation layer to scale the RGB value to 0 and 1
model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3))),

model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())


model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())
          
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())


model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(BatchNormalization())

# we will try to reduce overfitting by adding dropout
model.add(Dropout(0.3))

# convert layer into 1-D
model.add(Flatten())

# fully connected layer
model.add(Dense(256, activation='relu'))

# we will try to reduce overfitting by adding dropout
model.add(Dropout(0.25))

# the output layer
model.add(Dense(len(class_names)))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_40 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_30 (MaxPooli  (None, 90, 90, 16)        0
#  ng2D)
#
#  batch_normalization_6 (Bat  (None, 90, 90, 16)        64
#  chNormalization)
#
#  conv2d_41 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_31 (MaxPooli  (None, 45, 45, 32)        0
#  ng2D)
#
#  batch_normalization_7 (Bat  (None, 45, 45, 32)        128
#  chNormalization)
#
#  conv2d_42 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_32 (MaxPooli  (None, 22, 22, 64)        0
#  ng2D)
#
#  batch_normalization_8 (Bat  (None, 22, 22, 64)        256
#  chNormalization)
#
#  conv2d_43 (Conv2D)          (None, 22, 22, 128)       73856
#
#  max_pooling2d_33 (MaxPooli  (None, 11, 11, 128)       0
#  ng2D)
#
#  batch_normalization_9 (Bat  (None, 11, 11, 128)       512
#  chNormalization)
#
#  conv2d_44 (Conv2D)          (None, 11, 11, 128)       147584
#
#  conv2d_45 (Conv2D)          (None, 11, 11, 128)       147584
#
#  max_pooling2d_34 (MaxPooli  (None, 5, 5, 128)         0
#  ng2D)
#
#  batch_normalization_10 (Ba  (None, 5, 5, 128)         512
#  tchNormalization)
#
#  conv2d_46 (Conv2D)          (None, 5, 5, 256)         295168
#
#  conv2d_47 (Conv2D)          (None, 5, 5, 256)         590080
#
#  max_pooling2d_35 (MaxPooli  (None, 2, 2, 256)         0
#  ng2D)
#
#  batch_normalization_11 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten_5 (Flatten)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 256)               262400
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 9)                 2313
#
# =================================================================
# Total params: 1545065 (5.89 MB)
# Trainable params: 1543817 (5.89 MB)
# Non-trainable params: 1248 (4.88 KB)
# _________________________________________________________________

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.

history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs) # your model fit code
# Out:
# Epoch 1/50
# 506/506 [==============================] - 432s 844ms/step - loss: 1.4680 - accuracy: 0.4677 - val_loss: 1.5893 - val_accuracy: 0.4386
# Epoch 2/50
# 506/506 [==============================] - 401s 792ms/step - loss: 1.0239 - accuracy: 0.6164 - val_loss: 1.0136 - val_accuracy: 0.6222
# Epoch 3/50
# 164/506 [========>.....................] - ETA: 4:17 - loss: 0.8139 - accuracy: 0.6892

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# Class rebalance helps in improving the performance. After reducing class imbalance and adding dropout layer along with normalization the accuracy has increases significantly and also overfitting is under check as well.
